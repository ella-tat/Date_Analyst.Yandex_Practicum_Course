# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-файла-с-данными-и-общей-информации" data-toc-modified-id="Изучение-файла-с-данными-и-общей-информации-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение файла с данными и общей информации</a></span></li><li><span><a href="#Исследовательский-анализ-данных-(EDA)" data-toc-modified-id="Исследовательский-анализ-данных-(EDA)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследовательский анализ данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#Изучение-датасета,-средние-значения-и-стандартные-отклонения" data-toc-modified-id="Изучение-датасета,-средние-значения-и-стандартные-отклонения-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изучение датасета, средние значения и стандартные отклонения</a></span></li><li><span><a href="#Средние-значения-факт-оттока-в-текущем-месяце-признаков-в-двух-группах-—-ушедшие-/-оставшиеся" data-toc-modified-id="Средние-значения-факт-оттока-в-текущем-месяце-признаков-в-двух-группах-—-ушедшие-/-оставшиеся-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Средние значения факт оттока в текущем месяце признаков в двух группах — ушедшие / оставшиеся</a></span></li><li><span><a href="#Столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток);" data-toc-modified-id="Столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток);-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);</a></span></li><li><span><a href="#Постройте-матрицу-корреляций-и-отобразите-её" data-toc-modified-id="Постройте-матрицу-корреляций-и-отобразите-её-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Постройте матрицу корреляций и отобразите её</a></span></li></ul></li><li><span><a href="#Постройте-модель-прогнозирования-оттока-клиентов" data-toc-modified-id="Постройте-модель-прогнозирования-оттока-клиентов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Постройте модель прогнозирования оттока клиентов</a></span><ul class="toc-item"><li><span><a href="#Модель-бинарной-классификации-клиентов,-где-целевой-признак-—-факт-оттока-клиента-в-следующем-месяце:" data-toc-modified-id="Модель-бинарной-классификации-клиентов,-где-целевой-признак-—-факт-оттока-клиента-в-следующем-месяце:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце:</a></span><ul class="toc-item"><li><span><a href="#Разбейте-данные-на-обучающую-и-валидационную-выборку-функцией" data-toc-modified-id="Разбейте-данные-на-обучающую-и-валидационную-выборку-функцией-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Разбейте данные на обучающую и валидационную выборку функцией</a></span></li><li><span><a href="#Обучим-модель-на-train-выборке-двумя-способами:-логистической-регрессией,-случайным-лесом." data-toc-modified-id="Обучим-модель-на-train-выборке-двумя-способами:-логистической-регрессией,-случайным-лесом.-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Обучим модель на train-выборке двумя способами: логистической регрессией, случайным лесом.</a></span></li><li><span><a href="#Оценим-метрики-accuracy,-precision-и-recall-для-обеих-моделей-на-валидационной-выборке.-Сравните-по-ним-модели.-Какая-модель-показала-себя-лучше-на-основании-метрик?" data-toc-modified-id="Оценим-метрики-accuracy,-precision-и-recall-для-обеих-моделей-на-валидационной-выборке.-Сравните-по-ним-модели.-Какая-модель-показала-себя-лучше-на-основании-метрик?-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Оценим метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?</a></span></li></ul></li></ul></li><li><span><a href="#Кластеризация-клиентов" data-toc-modified-id="Кластеризация-клиентов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Кластеризация клиентов</a></span><ul class="toc-item"><li><span><a href="#Постройте-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисуйте-дендрограмму." data-toc-modified-id="Постройте-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисуйте-дендрограмму.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Постройте матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуйте дендрограмму.</a></span></li><li><span><a href="#Обучим-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозируем-кластеры-клиентов." data-toc-modified-id="Обучим-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозируем-кластеры-клиентов.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов.</a></span></li><li><span><a href="#Посмотрим-на-средние-значения-признаков-для-кластеров." data-toc-modified-id="Посмотрим-на-средние-значения-признаков-для-кластеров.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Посмотрим на средние значения признаков для кластеров.</a></span></li><li><span><a href="#Постройте-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?" data-toc-modified-id="Постройте-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?</a></span></li><li><span><a href="#Для-каждого-полученного-кластера-посчитайте-долю-оттока-(методом-groupby()).-Отличаются-ли-они-по-доле-оттока?-Какие-кластеры-склонны-к-оттоку,-а-какие-—-надёжны?" data-toc-modified-id="Для-каждого-полученного-кластера-посчитайте-долю-оттока-(методом-groupby()).-Отличаются-ли-они-по-доле-оттока?-Какие-кластеры-склонны-к-оттоку,-а-какие-—-надёжны?-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Для каждого полученного кластера посчитайте долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?</a></span></li></ul></li><li><span><a href="#Формулирование-выводов" data-toc-modified-id="Формулирование-выводов-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Формулирование выводов</a></span></li></ul></div>

# %% [markdown]
# # Описание проекта

# %% [markdown]
#  Заказчик - сеть фитнес-центров «Культурист-датасаентист».
#
# Цель исследования - провести анализ и подготовить план действий по удержанию клиентов фитнес-клуба.
#
#   Задачи для исследования:
# - научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
# - сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
# - проанализировать основные признаки, наиболее сильно влияющие на отток;
# - сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
# 1) выделить целевые группы клиентов;
# 2) предложить меры по снижению оттока;
# 3) определить другие особенности взаимодействия с клиентами.

# %% [markdown]
# ##  Изучение файла с данными и общей информации

# %%
# отключим предупреждения Anaconda
import warnings
warnings.filterwarnings('ignore')
# импорт библиотек
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
from plotly import graph_objects as go
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, silhouette_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

# %%
# чтение файлa с данными
df=pd.read_csv('/datasets/gym_churn.csv')

# %%
# общая информация о файлах данных таблицы
for row in df: 
  display('{}'.format(row), df[row].value_counts())
# Out:
# 'gender'
# 1    2041
# 0    1959
# Name: gender, dtype: int64
# 'Near_Location'
# 1    3381
# 0     619
# Name: Near_Location, dtype: int64
# 'Partner'
# 0    2053
# 1    1947
# Name: Partner, dtype: int64
# 'Promo_friends'
# 0    2766
# 1    1234
# Name: Promo_friends, dtype: int64
# 'Phone'
# 1    3614
# 0     386
# Name: Phone, dtype: int64
# 'Contract_period'
# 1     2207
# 12     960
# 6      833
# Name: Contract_period, dtype: int64
# 'Group_visits'
# 0    2351
# 1    1649
# Name: Group_visits, dtype: int64
# 'Age'
# 29    468
# 30    457
# 28    447
# 31    434
# 27    378
# 32    364
# 26    300
# 33    253
# 25    231
# 34    174
# 24    148
# 35     98
# 23     82
# 36     48
# 22     33
# 37     29
# 21     24
# 20     14
# 38     10
# 39      3
# 19      2
# 18      2
# 41      1
# Name: Age, dtype: int64
# 'Avg_additional_charges_total'
# 14.227470     1
# 17.082321     1
# 278.204461    1
# 120.457631    1
# 130.711299    1
#              ..
# 92.329635     1
# ...

# %%
# выведем первые 5 строк таблицы
df.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %%
# общая информация файла данных таблицы
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %%
# посмотрим на типы данных столбцов
df.dtypes
# Out:
# gender                                 int64
# Near_Location                          int64
# Partner                                int64
# Promo_friends                          int64
# Phone                                  int64
# Contract_period                        int64
# Group_visits                           int64
# Age                                    int64
# Avg_additional_charges_total         float64
# Month_to_end_contract                float64
# Lifetime                               int64
# Avg_class_frequency_total            float64
# Avg_class_frequency_current_month    float64
# Churn                                  int64
# dtype: object

# %%
# количество строк и столбцов
df.shape
# Out:
# (4000, 14)

# %% [markdown]
# # Описание данных

# %% [markdown]
# Всего в таблице 14 столбцов, 4000 строк.
# В таблице два типа данных: float64(4), int64(10).
#
# Таблица содержат информацию о столбцах:
#
# Данные клиента за предыдущий до проверки факта оттока месяц:
# - 'gender' — пол;
# - 'Near_Location' — проживание или работа в районе, где находится фитнес-центр;
# - 'Partner' — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
# - Promo_friends — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
# - 'Phone' — наличие контактного телефона;
# - 'Age' — возраст;
# - 'Lifetime' — время с момента первого обращения в фитнес-центр (в месяцах).
#
#     Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
# - 'Contract_period' — длительность текущего действующего абонемента (месяц, 6 месяцев, год);
# - 'Month_to_end_contract' — срок до окончания текущего действующего абонемента (в месяцах);
# - 'Group_visits' — факт посещения групповых занятий;
# - 'Avg_class_frequency_total' — средняя частота посещений в неделю за все время с начала действия абонемента;
# - 'Avg_class_frequency_current_month' — средняя частота посещений в неделю за предыдущий месяц;
# - 'Avg_additional_charges_total' — суммарная выручка от других услуг фитнес-центра: кафе, спорттовары, косметический и массажный салон.
# - 'Churn' — факт оттока в текущем месяце.
#
#     Выводы:
# - необходимо привести назнавания столбцов к нижнему регистру
# - поменять тип данных в столбцах с булевыми значениями 'gender','near_location', 'partner', 'promo_friends', 'phone', 'group_visits', 'churn'с числового на булевый и в столбце с данными о месяцах month_to_end_contract перевести из вещественного в цисловой тип данных.
# - пропуски и дубликаты не обнаружены.
# - проведисти исследовательский анализ данных (EDA):
#   1.проверить на отсутствующие признаки, изучить средние значения и стандартные отклонения (методом describe);
#   2.посмотреть на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (методом groupby);
#   3.построить столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);
#   4.построить матрицу корреляций.
# - построить модель прогнозирования оттока клиентов:
#   1.построить модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце:
#   2.разбить данные на обучающую и валидационную выборку функцией train_test_split().
#   3.обучить модель на train-выборке двумя способами: логистической регрессией и случайным лесом.
#   4.оценить метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели и определить, какая модель показала себя лучше на основании метрик?
# - сделать кластеризацию клиентов
#   1.провести кластеризацию объектов (клиентов) и стандартизировать данные.
#   2.построить матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисовать дендрограмму.
#   3.обучить модель кластеризации на основании алгоритма K-Means и спрогнозировать кластеры клиентов (число кластеров n=5).
#   4.посчитать средние значения признаков для кластеров.
#   5.построить распределения признаков для кластеров.
#   6.для каждого полученного кластера посчитать долю оттока и выявить кластеры склонные к оттоку.
# - сформулировать выводы и сделать базовые рекомендации по работе с клиентами для стратегии взаимодействия с клиентами и их удержания.

# %% [markdown]
# ## Исследовательский анализ данных (EDA)

# %% [markdown]
# ### Изучение датасета, средние значения и стандартные отклонения

# %%
# выведем названия столбцов
df.columns.tolist()
# Out:
# ['gender',
#  'Near_Location',
#  'Partner',
#  'Promo_friends',
#  'Phone',
#  'Contract_period',
#  'Group_visits',
#  'Age',
#  'Avg_additional_charges_total',
#  'Month_to_end_contract',
#  'Lifetime',
#  'Avg_class_frequency_total',
#  'Avg_class_frequency_current_month',
#  'Churn']

# %%
# приведем названия столбцов к нижнему регистру
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['gender', 'near_location', 'partner', 'promo_friends', 'phone',
#        'contract_period', 'group_visits', 'age',
#        'avg_additional_charges_total', 'month_to_end_contract', 'lifetime',
#        'avg_class_frequency_total', 'avg_class_frequency_current_month',
#        'churn'],
#       dtype='object')

# %%
# отсортируем таблицу в порядке убывания на предмет пропусков
df.isna().sum()
# Out:
# gender                               0
# near_location                        0
# partner                              0
# promo_friends                        0
# phone                                0
# contract_period                      0
# group_visits                         0
# age                                  0
# avg_additional_charges_total         0
# month_to_end_contract                0
# lifetime                             0
# avg_class_frequency_total            0
# avg_class_frequency_current_month    0
# churn                                0
# dtype: int64

# %%
# проверим на дубликаты 
df.duplicated().sum()
# Out:
# 0

# %%
# приведем столбцы с булевыми значениями,  к нужному типу данных
for columns in [
    'gender','near_location', 'partner', 'promo_friends', 'phone', 'group_visits', 'churn']:
    df[columns]=df[columns].astype('bool')
    print(df[columns].dtypes)
# Out:
# bool
# bool
# bool
# bool
# bool
# bool
# bool

# %%
# приведем столбцец данными о месяцах из вещественного в целочисленный тип данных
df['month_to_end_contract'] = df['month_to_end_contract'].astype('int')
df['month_to_end_contract'].dtypes
# Out:
# dtype('int32')

# %%
# посчитаем количество клиентов по полу
gender=pd.concat([df['gender'].value_counts(),\
                 df['gender'].value_counts(normalize=True)], axis=1)
gender.columns=['count', 'ratio']
gender.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_76929_row0_col0, #T_76929_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_76929_row1_col0, #T_76929_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_76929_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76929_level0_row0" class="row_heading level0 row0" >True</th>
#       <td id="T_76929_row0_col0" class="data row0 col0" >2041</td>
#       <td id="T_76929_row0_col1" class="data row0 col1" >51.02%</td>
#     </tr>
#     <tr>
#       <th id="T_76929_level0_row1" class="row_heading level0 row1" >False</th>
#       <td id="T_76929_row1_col0" class="data row1 col0" >1959</td>
#       <td id="T_76929_row1_col1" class="data row1 col1" >48.98%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# из имеющихся данных, распределение клиентов по полу можно считать нормальным, примерно одинаковое количество, разница только в 1%

# %%
# посчитаем количество клиентов проживающих или работающих в районе, где находится фитнес-центр
near_location=pd.concat([df['near_location'].value_counts(),\
                 df['near_location'].value_counts(normalize=True)], axis=1)
near_location.columns=['count', 'ratio']
near_location.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_de62a_row0_col0, #T_de62a_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_de62a_row1_col0, #T_de62a_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_de62a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de62a_level0_row0" class="row_heading level0 row0" >True</th>
#       <td id="T_de62a_row0_col0" class="data row0 col0" >3381</td>
#       <td id="T_de62a_row0_col1" class="data row0 col1" >84.52%</td>
#     </tr>
#     <tr>
#       <th id="T_de62a_level0_row1" class="row_heading level0 row1" >False</th>
#       <td id="T_de62a_row1_col0" class="data row1 col0" >619</td>
#       <td id="T_de62a_row1_col1" class="data row1 col1" >15.47%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# более 84% клиентов проживают или работают рядом с фитнес-центром, это сильный признак

# %%
# посчитаем количество клиентов являющихся сотрудниками компании-партнёра клуба
partner=pd.concat([df['partner'].value_counts(),\
                 df['partner'].value_counts(normalize=True)], axis=1)
partner.columns=['count', 'ratio']
partner.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_97cd7_row0_col0, #T_97cd7_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_97cd7_row1_col0, #T_97cd7_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_97cd7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97cd7_level0_row0" class="row_heading level0 row0" >False</th>
#       <td id="T_97cd7_row0_col0" class="data row0 col0" >2053</td>
#       <td id="T_97cd7_row0_col1" class="data row0 col1" >51.32%</td>
#     </tr>
#     <tr>
#       <th id="T_97cd7_level0_row1" class="row_heading level0 row1" >True</th>
#       <td id="T_97cd7_row1_col0" class="data row1 col0" >1947</td>
#       <td id="T_97cd7_row1_col1" class="data row1 col1" >48.68%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# почти половина клиентов, более 48% являются сотрудниками компании-партнёра клуба

# %%
# посчитаем количество клиентов использовавших промо-код от знакомого при оплате первого абонемента
promo_friends=pd.concat([df['promo_friends'].value_counts(),\
                 df['promo_friends'].value_counts(normalize=True)], axis=1)
promo_friends.columns=['count', 'ratio']
promo_friends.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_618a9_row0_col0, #T_618a9_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_618a9_row1_col0, #T_618a9_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_618a9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_618a9_level0_row0" class="row_heading level0 row0" >False</th>
#       <td id="T_618a9_row0_col0" class="data row0 col0" >2766</td>
#       <td id="T_618a9_row0_col1" class="data row0 col1" >69.15%</td>
#     </tr>
#     <tr>
#       <th id="T_618a9_level0_row1" class="row_heading level0 row1" >True</th>
#       <td id="T_618a9_row1_col0" class="data row1 col0" >1234</td>
#       <td id="T_618a9_row1_col1" class="data row1 col1" >30.85%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# более 30% клиентов использовали промокод

# %%
# посчитаем количество клиентов оставивших номер телефона
phone=pd.concat([df['phone'].value_counts(),\
                 df['phone'].value_counts(normalize=True)], axis=1)
phone.columns=['count', 'ratio']
phone.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_0aad2_row0_col0, #T_0aad2_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0aad2_row1_col0, #T_0aad2_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_0aad2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0aad2_level0_row0" class="row_heading level0 row0" >True</th>
#       <td id="T_0aad2_row0_col0" class="data row0 col0" >3614</td>
#       <td id="T_0aad2_row0_col1" class="data row0 col1" >90.35%</td>
#     </tr>
#     <tr>
#       <th id="T_0aad2_level0_row1" class="row_heading level0 row1" >False</th>
#       <td id="T_0aad2_row1_col0" class="data row1 col0" >386</td>
#       <td id="T_0aad2_row1_col1" class="data row1 col1" >9.65%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# более 90% клиентов оставили свой контактный номер телефона, сильный признак

# %%
# посчитаем длительность текущего действующего абонемента (месяц, 6 месяцев, год)
contract_period=pd.concat([df['contract_period'].value_counts(),\
                 df['contract_period'].value_counts(normalize=True)], axis=1)
contract_period.columns=['count', 'ratio']
contract_period.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_99666_row0_col0, #T_99666_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_99666_row1_col0, #T_99666_row1_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_99666_row2_col0, #T_99666_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_99666_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99666_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_99666_row0_col0" class="data row0 col0" >2207</td>
#       <td id="T_99666_row0_col1" class="data row0 col1" >55.17%</td>
#     </tr>
#     <tr>
#       <th id="T_99666_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_99666_row1_col0" class="data row1 col0" >960</td>
# ...

# %% [markdown]
# более 55% клиентов предпочитают брать абонемент на 1 месяц, с небольшой разницей клиенты берут абонемент на год - 24% и полгода 21%, в половине случаев клиенты не настроены на долгосрочные визиты в фитнес-клуб

# %%
# посчитаем срок до окончания текущего действующего абонемента (в месяцах)
month=pd.concat([df['month_to_end_contract'].value_counts(),\
                 df['month_to_end_contract'].value_counts(normalize=True)], axis=1)
month.columns=['count', 'ratio']
month.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_42e83_row0_col0, #T_42e83_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_42e83_row1_col0, #T_42e83_row1_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_42e83_row2_col0, #T_42e83_row2_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_42e83_row3_col0, #T_42e83_row3_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_42e83_row4_col0, #T_42e83_row4_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_42e83_row5_col0, #T_42e83_row5_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_42e83_row6_col0, #T_42e83_row6_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_42e83_row7_col0, #T_42e83_row7_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_42e83_row8_col0, #T_42e83_row8_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_42e83_row9_col0, #T_42e83_row9_col1, #T_42e83_row10_col0, #T_42e83_row10_col1 {
# ...

# %% [markdown]
# клиенты с абонементом на месяц естественно на 1 месте и составляют более 55%

# %%
# посчитаем факт посещения групповых занятий
group_visits=pd.concat([df['group_visits'].value_counts(),\
                 df['group_visits'].value_counts(normalize=True)], axis=1)
group_visits.columns=['count', 'ratio']
group_visits.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_d1cc3_row0_col0, #T_d1cc3_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d1cc3_row1_col0, #T_d1cc3_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_d1cc3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1cc3_level0_row0" class="row_heading level0 row0" >False</th>
#       <td id="T_d1cc3_row0_col0" class="data row0 col0" >2351</td>
#       <td id="T_d1cc3_row0_col1" class="data row0 col1" >58.77%</td>
#     </tr>
#     <tr>
#       <th id="T_d1cc3_level0_row1" class="row_heading level0 row1" >True</th>
#       <td id="T_d1cc3_row1_col0" class="data row1 col0" >1649</td>
#       <td id="T_d1cc3_row1_col1" class="data row1 col1" >41.23%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# клиенты предпочитают групповые занятия, только в 41% случаев

# %%
# создадим общую функцию для гистограмм
def chart(fig, title,yaxis_title,xaxis_title):
    fig = fig
    fig.update_layout(
    width=700,
    height=400,
    title=title,
    yaxis_title=yaxis_title,
    xaxis_title=xaxis_title
    )
    fig.show()

# %%
# гистограмма средней частоты посещений в неделю за предыдущий месяц
chart(px.histogram(df, x="avg_class_frequency_current_month"),
      'Гистограмма средней частоты посещений в неделю за предыдущий месяц',
      'Неделя',
      'Дата')
# Out:
# <div>                            <div id="817623c1-8574-4ae7-ab55-fe09065aef44" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("817623c1-8574-4ae7-ab55-fe09065aef44")) {                    Plotly.newPlot(                        "817623c1-8574-4ae7-ab55-fe09065aef44",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"avg_class_frequency_current_month=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0.0,1.9102435215196407,1.7365018916344137,3.3572145130526616,1.120078107422207,2.6370069647681804,1.2772416305372298,1.0493871451868677,1.059332976736446,1.9513676552017305,1.36771396663351,1.5843158272
# ...

# %% [markdown]
# пик приходится на первый день, что логично, далее идет резкий спад посещений и начинает рости примерно до 2 недель, и начинается резкий спад посещений, к 6 неделе посещений сводятся к 1

# %%
# гистограмма средняя частота посещений в неделю за все время с начала действия абонемента
chart(px.histogram(df, x="avg_class_frequency_total"),
      'Гистограмма средней частота посещений в неделю за все время с начала действия абонемента',
      'Неделя',
      'Частота')
# Out:
# <div>                            <div id="9e021c23-646f-48e1-9248-94f365b08b4f" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e021c23-646f-48e1-9248-94f365b08b4f")) {                    Plotly.newPlot(                        "9e021c23-646f-48e1-9248-94f365b08b4f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"avg_class_frequency_total=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0.0203979476208577,1.9229360550418195,1.8590983473832376,3.2056327682385,1.1138844004257795,2.6234768072839807,1.138941228411322,1.2135019626583017,1.106238932529013,1.81085190458252,1.6411796616862384,2.348535
# ...

# %% [markdown]
# пик приходится примерно на 2 неделю, к 3 неделе начинается резкое снижение, картина похожа на предыдущую гистограмму

# %%
# посчитаем время с момента первого обращения в фитнес-центр (в месяцах).
lifetime=pd.concat([df['lifetime'].value_counts(),\
                 df['lifetime'].value_counts(normalize=True)], axis=1)
lifetime.columns=['count', 'ratio']
lifetime.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_45821_row0_col0, #T_45821_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_45821_row1_col0, #T_45821_row1_col1 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_45821_row2_col0, #T_45821_row2_col1 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_45821_row3_col0, #T_45821_row3_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_45821_row4_col0, #T_45821_row4_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_45821_row5_col0, #T_45821_row5_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_45821_row6_col0, #T_45821_row6_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_45821_row7_col0, #T_45821_row7_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_45821_row8_col0, #T_45821_row8_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_45821_row9_col0, #T_45821_row9_col1 {
#   background-color: #dfecf7;
# ...

# %% [markdown]
# пик приходится на 1 месяц, большая часть клиентов обратилась в первые 4 месяца, к концу имеются только еденицы

# %%
# посчитаем факт оттока в текущем месяце
churn=pd.concat([df['churn'].value_counts(),\
                 df['churn'].value_counts(normalize=True)], axis=1)
churn.columns=['count', 'ratio']
churn.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_51a7d_row0_col0, #T_51a7d_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_51a7d_row1_col0, #T_51a7d_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_51a7d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51a7d_level0_row0" class="row_heading level0 row0" >False</th>
#       <td id="T_51a7d_row0_col0" class="data row0 col0" >2939</td>
#       <td id="T_51a7d_row0_col1" class="data row0 col1" >73.47%</td>
#     </tr>
#     <tr>
#       <th id="T_51a7d_level0_row1" class="row_heading level0 row1" >True</th>
#       <td id="T_51a7d_row1_col0" class="data row1 col0" >1061</td>
#       <td id="T_51a7d_row1_col1" class="data row1 col1" >26.52%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# отток в текущем месяце составляет более 26%, почти треть клиентов клуба ушла

# %%
# посчитаем клиентов по возрасту
age=pd.concat([df['age'].value_counts(),\
               df['age'].value_counts(normalize=True)], axis=1)
age.columns=['count', 'ratio']
age.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_9beea_row0_col0, #T_9beea_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9beea_row1_col0, #T_9beea_row1_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_9beea_row2_col0, #T_9beea_row2_col1 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_9beea_row3_col0, #T_9beea_row3_col1 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_9beea_row4_col0, #T_9beea_row4_col1 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_9beea_row5_col0, #T_9beea_row5_col1 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_9beea_row6_col0, #T_9beea_row6_col1 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_9beea_row7_col0, #T_9beea_row7_col1 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_9beea_row8_col0, #T_9beea_row8_col1 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_9beea_row9_col0, #T_9beea_row9_col1 {
#   background-color: #a0cbe2;
# ...

# %% [markdown]
# основная часть клиентов в возрасте от 27 до 32 лет

# %%
# статистическая сводка
df.describe().T.style.format('{:.2f}').background_gradient(cmap='Blues', axis=1)
# Out:
# <style type="text/css">
# #T_f094e_row0_col0, #T_f094e_row1_col0, #T_f094e_row2_col0, #T_f094e_row3_col0, #T_f094e_row4_col0, #T_f094e_row5_col0, #T_f094e_row6_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f094e_row0_col1, #T_f094e_row0_col2, #T_f094e_row0_col3, #T_f094e_row0_col4, #T_f094e_row0_col5, #T_f094e_row0_col6, #T_f094e_row0_col7, #T_f094e_row1_col2, #T_f094e_row1_col3, #T_f094e_row2_col3, #T_f094e_row3_col1, #T_f094e_row3_col2, #T_f094e_row3_col3, #T_f094e_row3_col4, #T_f094e_row3_col5, #T_f094e_row3_col6, #T_f094e_row3_col7, #T_f094e_row4_col1, #T_f094e_row4_col2, #T_f094e_row4_col3, #T_f094e_row4_col4, #T_f094e_row4_col5, #T_f094e_row4_col6, #T_f094e_row5_col1, #T_f094e_row5_col2, #T_f094e_row5_col3, #T_f094e_row5_col4, #T_f094e_row5_col5, #T_f094e_row5_col6, #T_f094e_row5_col7, #T_f094e_row6_col1, #T_f094e_row6_col2, #T_f094e_row6_col3, #T_f094e_row6_col4, #T_f094e_row6_col5, #T_f094e_row6_col6, #T_f094e_row6_col7 {
#   background-color: #f7fbff;
# ...

# %%
# разделим столбцы по признакам: булевым и числовым без столбца с оттоком
bool_sings=[]
numeric_sings=[]
for col in df.loc[:, df.columns != 'churn'].columns.tolist():
    if df[col].dtype == 'bool':
        bool_sings.append(col)
    else:
        numeric_sings.append(col)

# %%
# визуализация описательной статистики
plt.figure(figsize =(12, 12))
col_count, row_count = 4,3
for i, column in enumerate(numeric_sings):
    sns.boxplot(y=column , data = df, 
                     ax=plt.subplot(col_count, row_count, i+1)
                    )
    plt.title(column) 
    plt.ylabel('Кол-во')
plt.suptitle('Распределение вероятностей переменных')
plt.tight_layout()

# %% [markdown]
# Судя по статистической сводке и ее визуализации, в столбцах:
# - contract_period - медиана и среднее различаются, так std показывает что значение среднего отклоняются +- на его значение 4.55, так как период до окончания срока абонемента от 1 до 12 месяцев
# - age - медиана и среднее примерно одинаковые, отклонение std незначительное
# - avg_additional_charges_total - медиана и среднее различаются, но не критично, выручка от других услуг фитнес-центра разная, поэтому и наблюдаются выбросы
# - month_to_end_contract - медиана и среднее различаются, так std показывает что значение среднего отклоняются +- на его значение 4.19, так как период до окончания срока абонемента от 1 до 12 месяцев
# - lifetime - медиана и среднее примерно одинаковые, среднее время с момента обращения составляет 3 месяца, с минимальным количеством клиентов до 31 месяца, выбросы это и показывают
# - avg_class_frequency_total - медиана и среднее примерно одинаковые, средняя частота посещений в неделю составляет 1.8
# - avg_class_frequency_current_month - медиана и среднее примерно одинаковые,  средней частоты посещений в неделю за предыдущий месяц, наблюдаются редкие выбросы, так как есть еденичные клиенты посещающие клуб каждый день

# %% [markdown]
# ### Средние значения факт оттока в текущем месяце признаков в двух группах — ушедшие / оставшиеся

# %%
# средние значения признаков в двух группах
df.groupby('churn').mean().style.format('{:.2f}').background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_572b9_row0_col0, #T_572b9_row1_col1, #T_572b9_row1_col2, #T_572b9_row1_col3, #T_572b9_row1_col4, #T_572b9_row1_col5, #T_572b9_row1_col6, #T_572b9_row1_col7, #T_572b9_row1_col8, #T_572b9_row1_col9, #T_572b9_row1_col10, #T_572b9_row1_col11, #T_572b9_row1_col12 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_572b9_row0_col1, #T_572b9_row0_col2, #T_572b9_row0_col3, #T_572b9_row0_col4, #T_572b9_row0_col5, #T_572b9_row0_col6, #T_572b9_row0_col7, #T_572b9_row0_col8, #T_572b9_row0_col9, #T_572b9_row0_col10, #T_572b9_row0_col11, #T_572b9_row0_col12, #T_572b9_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_572b9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >gender</th>
#       <th class="col_heading level0 col1" >near_location</th>
#       <th class="col_heading level0 col2" >partner</th>
# ...

# %% [markdown]
# - gender, пол никак не влияет на отток клиентов, среднее одинаковое
# - near_location, отток клиентов меньше, для проживающих или работающих в районе фитнес-центра +
# - partner, клиенты являющиеся сотрудниками компании-партнёра клуба, отток меньше +
# - promo_friends, по факту первоначальной записи в рамках акции «приведи друга» влияет на отток клиентов, пришедших по этой акции отток клиентов значительно меньше +
# - phone, наличие контактного телефона никак не влияет на отток клиентов -
# - contract_period, длительность текущего действующего абонемента, влияние этого признака очень сильное, абонемент стимулирует к посещению клуба ++
# - group_visits, факт посещения групповых занятий, оказывает положительное влияение на клиентов клуба(в группе тренироваться интересней) +
# - age, возраст, оказывает очень слабое влияние -
# - avg_additional_charges_total(суммарная выручка от других услуг фитнес-центра: кафе, спорттовары, косметический и массажный салон), слабо влияет на отток, что клиенты не тратятся на доп. услуги +
# - month_to_end_contract(срок до окончания текущего действующего абонемента) оказывает сильное положительное влияние, клиент оплатил абонемент, ему не хочется, чтобы его затраты пропали ++
# - lifetime(время с момента первого обращения в фитнес-центр) оказывает очень сильное положительное влияние, так вырабатывается привычка заниматься спортом ++
# - avg_class_frequency_total(средняя частота посещений в неделю за все время с начала действия абонемента) слабо, но влияет на отток клиентов +
# - avg_class_frequency_current_month(средняя частота посещений в неделю за предыдущий месяц)слабо, но влияет на отток клиентов +
# можно выделить, что положительное влияние на отток клиентов в большей степени оказывает: длительность  абонемента и время с момента первого обращения в фитнес-центр, чем длительнее абомемент по времени, а абонемент стоит денег, так у клиента вырабатывается привычка посещать фитнес-центр

# %% [markdown]
# ### Столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);

# %%
# визуализируем распределение признаков оттока, по булевому типу
plt.figure(figsize =(13, 10))
col_count, row_count = 2,3
for i, sings in enumerate(bool_sings):
    for churn in df['churn'].unique():
        current=df.query('churn == @churn')
        sns.distplot(current[sings], kde=False, bins=4, 
                     ax=plt.subplot(col_count, row_count, i+1)
                    )
    plt.title(sings) 
    _ = plt.legend(['остались-0','ушли-1'])
    plt.xticks([0,1])
    plt.ylabel('Количество', fontsize=10)
    plt.suptitle('Распределение признаков оттока клиентов по булевому типу')
plt.tight_layout()

# %% [markdown]
# - 'gender' - отток по полу примерно одинаковый, у 1 незначительно больше
# - 'near_location' - клентов, живущих и работающих ближе к фитнес-центру значительно больше, оставшихся клиентов значительно больше, чем ушедших
# - 'partner' - клиенты пришедшие по партнерской программе уходят в небольшом количестве
# - 'promo_friends' - клиентов по промо-акции значительно меньше, но остается их намного больше
# - 'phone' - большая часть клиентов оставили свой телефон, но больше трети клиентов ушли
# - 'group_visits' - клиенты посещающие групповые занятия склонны остаться.

# %%
# визуализируем распределение признаков оттока клиентов по числовому данными
plt.figure(figsize =(13, 12))
col_count, row_count = 3,3
for i, sings in enumerate(numeric_sings):
    for churn in df['churn'].unique():
        current=df.query('churn == @churn')
        sns.distplot(current[sings], label=churn, ax=plt.subplot(col_count, row_count, i+1)
                    )
    plt.title(sings) 
    _ = plt.legend(['остались-0','ушли-1'])
    plt.ylabel('Частота', fontsize=12)
plt.suptitle('Распределение признаков оттока клиентов по числовыми данными')
plt.tight_layout()

# %% [markdown]
# - 'contract_period' - основной отток у клиентов с абонементом на месяц, чем дольше абонемент, тем отток меньше.
# - 'age' - до возраста 25-27 лет большая часть склонна уйти, с 28-32 года клиенты склонны остаться
# - 'avg_additional_charges_total' - ушедшие чуть меньше платили за доп.услуги, большая часть оставшихся клиентов тратит на доп.услуги не больше 300.
# - 'month_to_end_contract' - основной отток у клиентов с абонементом 1 месяц, с  длительным абонементом клиенты остаются чаще.
# - 'lifetime' - основной отток идет от тех кто ходил первые несколько месяцев
# - 'avg_class_frequency_total' - основной отток у тех, кто ходит до 2 раз в неделю, клиенты посещающие фитнес-центр более 3 раз в неделю не уходят.
# - 'avg_class_frequency_current_month' - после 3 посещений в неделю отток почти отсутствует

# %% [markdown]
# ### Постройте матрицу корреляций и отобразите её

# %%
# корреляционная матрица
plt.figure(figsize = (16,7))
corr_m = df.corr()
sns.heatmap(corr_m,  cmap="BrBG", annot = True)# напишите ваш код здесь
plt.title('Матрица корреляций признаков', fontsize = 20)
plt.xlabel('Признаки', fontsize = 14) 
plt.ylabel('Признаки', fontsize = 14) 
plt.show()

# %% [markdown]
#     Выявлены мультиколлинеарные признаки
# - две пары пизнаков с очень сильной корреляцией:
# 1. сильную корреляцию 0.97 наблюдаем 'contract_period' и 'month_to_end_contract'- чем длительнее абонемент, тем больше месяцев осталось;
# 2. сильную корреляцию 0.95 наблюдаем  'avg_class_frequency_current_month' и 'avg_class_frequency_total' - клиенты с постоянным графиком, значит и за последний месяц график тот же.
#     Выявлены признаки с нулевой корреляцией с целевой переменной
#
# - 'gender' и 'phone' - никакого влияния, корреляция 0
#   В основном, все признаки слабо коррелируют

# %% [markdown]
# # Вывод

# %% [markdown]
# - из имеющихся данных, распределение клиентов по полу можно считать нормальным, примерно одинаковое количество, разница только в 1%
# - более 84% клиентов проживают или работают рядом с фитнес-центром, это сильный признак
# - почтии половина клиентов, более 48% являются сотрудниками компании-партнёра клуба
# - более 30% клиентов использовали промокод
# - более 90% клиентов оставили свой контактный номер телефона, сильный признак
# - более 55% клиентов предпочитают брать абонемент на 1 месяц, с небольшой разницей клиенты берут абонемент на год - 24% и полгода 21%, в половине случаев клиенты не настроены на долгосрочные визиты в фитнес-клуб
# - по сроку до окончания текущего действующего абонемента (в месяцах), клиенты с абонементом на месяц естественно на 1 месте и составляют более 55%
# - клиенты предпочитают групповые занятия, только в 41% случаев
# - по средней частота посещений в неделю за предыдущий месяц, пик приходится на первый день, что логично, далее идет резкий спад посещений и начинает рости примерно до 2 недель, и начинается резкий спад посещений, к 6 неделе посещений сводятся к 1
# - по средней частоте посещений в неделю за все время с начала действия абонемента, пик приходится примерно на 2 неделю, к 3 неделе начинается резкое снижение
# - по времени с момента первого обращения в фитнес-центр (в месяцах), большая часть клиентов обратилась в первые 4 месяца, к концу имеются только еденицы
# - отток в текущем месяце составляет более 26%, почти треть клиентов клуба уходят
# - основная часть клиентов в возрасте от 27 до 32 лет
# - по статистической сводке можно сказать, что распределение вполне расномерное, стандартное отклонение не критично далеко от среднего, есть незначительные выбросы
# - можно выделить, что положительное влияние на отток клиентов в большей степени оказывает: длительность  абонемента и время с момента первого обращения в фитнес-центр, чем длительнее абомемент по времени, а абонемент стоит денег, так у клиента вырабатывается привычка посещать фитнес-центр
# - выявились мультиколлинеарные признаки, две пары пизнаков с очень сильной корреляцией:
# 1. сильную корреляцию 0.97 наблюдаем 'contract_period' и 'month_to_end_contract'- чем длительнее абонемент, тем больше месяцев осталось;
# 2. сильную корреляцию 0.95 наблюдаем  'avg_class_frequency_current_month' и 'avg_class_frequency_total' - клиенты с постоянным графиком, значит и за последний месяц график тот же.

# %% [markdown]
# ## Постройте модель прогнозирования оттока клиентов

# %% [markdown]
# ###  Модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце:

# %% [markdown]
# #### Разбейте данные на обучающую и валидационную выборку функцией

# %%
# удалим мультиколлинеарные признаки
df.drop(['month_to_end_contract', 'avg_class_frequency_current_month'], axis = 1, inplace = True)

# %%
# разделим данные на признаки (матрица X) и целевую переменную (y)
X = df.drop(['churn'], axis=1) 
y = df['churn']

# %%
# разделим модель на обучающую и валидационную выборку
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# стандартизируем данные 
scaler = StandardScaler()
scaler.fit(X_train) # обучим scaler на обучающей выборке методом fit
X_train_st =scaler.transform(X_train) # стандартизируеме обучающую выборку методом transform scaler 
X_test_st = scaler.transform(X_test) # стандартизируем тестовую выборку методом transform scaler

# %% [markdown]
# #### Обучим модель на train-выборке двумя способами: логистической регрессией, случайным лесом.

# %%
# определим функцию, которая будет выводить наши метрики
def metrics(y_true, y_pred, y_proba, title):
    print(title)
    print('\tAccuracy: {:.2f}'.format(accuracy_score(y_true, y_pred)))
    print('\tPrecision: {:.2f}'.format(precision_score(y_true, y_pred)))
    print('\tRecall: {:.2f}'.format(recall_score(y_true, y_pred)))
        
# зададим алгоритм для модели логистической регрессии
lr_model = LogisticRegression(random_state=0)
# обучим модель
lr_model.fit(X_train_st, y_train)
# воспользуемся уже обученной моделью, чтобы сделать прогнозы
lr_predictions = lr_model.predict(X_test_st)
lr_probabilities = lr_model.predict_proba(X_test_st)[:, 1]
# выведем все метрики
metrics(
    y_test,
    lr_predictions,
    lr_probabilities,
    title='Метрики для модели логистической регрессии:',
)

# зададим алгоритм для новой модели на основе алгоритма случайного леса
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0) 
# обучим модель случайного леса
rf_model.fit(X_train_st, y_train)
# воспользуемся уже обученной моделью, чтобы сделать прогнозы
rf_predictions = rf_model.predict(X_test_st)
rf_probabilities = rf_model.predict_proba(X_test_st)[:,1]

# выведем все метрики
metrics(y_test, rf_predictions, rf_probabilities, 
    title='\nМетрики для модели случайного леса:'
)
# Out:
# Метрики для модели логистической регрессии:
# 	Accuracy: 0.90
# 	Precision: 0.79
# 	Recall: 0.81
#
# Метрики для модели случайного леса:
# 	Accuracy: 0.89
# 	Precision: 0.79
# 	Recall: 0.76

# %% [markdown]
# #### Оценим метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?

# %% [markdown]
# - по параметру Accuracy "Логистическая регрессия" лучше 0.90, чем "Случайный лес" 0.89
# - по Precision "Логистическая регрессия" и "Случайный лес" получили одинаковые показатели 0.79
# - по Recall "Логистическая регрессия" лучше 0.81, чем  и "Случайный лес" 0.76
# Почти по всем параметрам "Логистическая регрессия" дает результат немного лучше чем "Случайный лес"

# %% [markdown]
# # Вывод

# %% [markdown]
# Почти по всем параметрам "Логистическая регрессия" дает результат немного лучше чем "Случайный лес"

# %% [markdown]
# ## Кластеризация клиентов

# %% [markdown]
# ### Постройте матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуйте дендрограмму.

# %%
# обязательная стандартизация данных перед работой с алгоритмами
sc = StandardScaler()
X_sc = sc.fit_transform(df)
linked = linkage(X_sc, method = 'ward')

# %%
# визуализировать как дендрограмму
plt.figure(figsize=(15, 8))  
dendrogram(linked, orientation='top')
plt.title('Hierarchial clustering for GYM')
plt.show()

# %% [markdown]
# на дендограмме выделились 5 кластеров

# %% [markdown]
# ### Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов.

# %%
# задаём число кластеров, равное 5, и фиксируем значение random_state для воспроизводимости результата
km = KMeans(n_clusters=5, random_state=0) 
# применяем алгоритм к данным и формируем вектор кластеров 
labels = km.fit_predict(df) 
# таблица «связок» между объектами
df['cluster'] = labels

# %%
# посчитаем метрику силуэта для нашей кластеризации
print('Silhouette_score: {:.2f}'.format(silhouette_score(X_sc, labels)))
# Out:
# Silhouette_score: 0.01

# %% [markdown]
# Значение метрики силуэта принимает значения от -1 до 1. Чем ближе к 1, тем качественнее кластеризация. В нашем случае кластеризация не качественная 0.01

# %% [markdown]
# ### Посмотрим на средние значения признаков для кластеров.

# %%
# посчитаем количество клиентов в кластерах
cluster=pd.concat([df['cluster'].value_counts(),\
               df['cluster'].value_counts(normalize=True)], axis=1)
cluster.columns=['count', 'ratio']
cluster.style.format({'ratio':'{:.2%}'}).background_gradient(cmap='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_e4088_row0_col0, #T_e4088_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e4088_row1_col0, #T_e4088_row1_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_e4088_row2_col0, #T_e4088_row2_col1 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_e4088_row3_col0, #T_e4088_row3_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_e4088_row4_col0, #T_e4088_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_e4088_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4088_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_e4088_row0_col0" class="data row0 col0" >1030</td>
#       <td id="T_e4088_row0_col1" class="data row0 col1" >25.75%</td>
# ...

# %% [markdown]
# кластеры 4, 0 имеют почти однинаковое количество клиентов, меньше всего в кластере 3

# %%
# средние значения признаков для кластеров
df.groupby('cluster').mean().T.style.format('{:.2f}').background_gradient(cmap='Blues', axis=1)
# Out:
# <style type="text/css">
# #T_3a363_row0_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_3a363_row0_col1, #T_3a363_row1_col1, #T_3a363_row2_col3, #T_3a363_row3_col1, #T_3a363_row4_col3, #T_3a363_row5_col3, #T_3a363_row6_col1, #T_3a363_row7_col3, #T_3a363_row8_col3, #T_3a363_row9_col3, #T_3a363_row10_col3, #T_3a363_row11_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3a363_row0_col2 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_3a363_row0_col3, #T_3a363_row1_col0, #T_3a363_row2_col4, #T_3a363_row3_col4, #T_3a363_row4_col4, #T_3a363_row5_col0, #T_3a363_row6_col0, #T_3a363_row7_col0, #T_3a363_row8_col0, #T_3a363_row9_col0, #T_3a363_row10_col0, #T_3a363_row11_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3a363_row0_col4 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_3a363_row1_col2 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_3a363_row1_col3 {
#   background-color: #58a1cf;
# ...

# %% [markdown]
# - почти по всем признакам можно выделить кластер 1 и 3, но показатели кластера 3 немного лучше: контрактный период самый большой, траты на доп.услуги самые большие, клиенты посещают клуб с частотой более 2 раз в неделю, показатель по оттоку самый маленький по всем кластерам, что может говорить, в этом кластере отток клиентов самый маленький, но в этом кластере меньше всего клиентов 6.78%

# %% [markdown]
# ### Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?

# %%
# визуализируем распределение признаков для кластеров по булевому типу
plt.figure(figsize =(10, 16))
col_count, row_count = 4,2
for i, sings in enumerate(bool_sings):
    for cluster in df['cluster'].unique():
        current=df.query('cluster == @cluster')
        sns.distplot(current[sings], kde=False, bins=4, label=cluster, 
                     ax=plt.subplot(col_count, row_count, i+1)
            )
    plt.title(sings) 
    plt.legend()
    plt.xticks([True, False])
    plt.ylabel('Количество', fontsize=10)
plt.suptitle('Распределение признаков для кластеров по булевому типу')
plt.tight_layout()

# %% [markdown]
# - 'gender' - распределение в кластерах по полу почти равномерное
# - 'near_location' - во всех кластерах клиенты в большей степени проживают или работают рядом с клубом, не близко выделяется кластер 0, там больше всего клиентов
# - 'partner' - кластер 0,1,3 и 2 выделяются в нем примерно одинаковое количество являются и не являются партнерами, в кластере 4 больше клиентов не являются партнерами
# - 'promo_friends' - кластеры 4 и 0 - те кто не по акции «приведи друга», кластер 2 выделяется там клиентов больше по акции.
# - 'phone' - в кластере 4 больше всего тех, кто не сотавил телефон
# - 'group_visits' - в кластерах 0, 4, 2 - не любят групповые занятия. в кластере 3 примерно одинаковое количество клиентов посещают и не посещают групповые занятия.

# %%
# удалим мультиколлинеарные признаки из листа
for name_list in ['month_to_end_contract', 'avg_class_frequency_current_month']:
    numeric_sings.remove(name_list)

# %%
# визуализируем распределение столбцов по числовому признаку
plt.figure(figsize =(13, 13))
col_count, row_count = 3,2
for i, sings in enumerate(numeric_sings):
    for cluster in df['cluster'].unique():
        current=df.query('cluster == @cluster')
        sns.distplot(current[sings], bins=10, label=cluster,
                     ax=plt.subplot(col_count, row_count, i+1)
                    )
    plt.title(sings) 
    plt.legend()
    plt.ylabel('Частота', fontsize=12)
plt.suptitle('Распределение столбцов по числовому признаку')
plt.tight_layout()

# %% [markdown]
# - 'contract_period' - больше всего приобретают тариф на месяц, в кластере 0 и 4 больше всего, выбирают тариф на 1 месяц,  в кластере 3 выбирают тариф на 12 месяцев, чаще чем в остальных кластерах.
# - 'age' - в кластере 0 и 4 клиенты в основном до 30 лет, в кластере 1 в основном 30, в кластере 2 и 3 в основном состоит из тех кому за 30 лет и больше.
# - 'avg_additional_charges_total' - в кластере 3 тратят больше 300 за доп.услуги, клиенты кому за 30, могут позволить траты, в кластере 0 тратится не любят, до 100, там как раз преимущественно молодежь, еще мало зарабатывают.
# - 'lifetime' - выделяются кластеры кластеры 3 и немного меньше 1 кластер, здесь клиенты ходят в клуб более 4 месяцев.
# - 'avg_class_frequency_total' - выделяется кластер 3, смещение вправо, в отличие от остальных кластеров, посещение клуба с частотой более 2 раз в неделю.

# %% [markdown]
# ### Для каждого полученного кластера посчитайте долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?

# %%
# посчитаем долю оттока клиентов
(df.query('churn == True').groupby('churn')['cluster'].value_counts(normalize=True)
                          .to_frame().style.format('{:.2%}').background_gradient(cmap='Blues', axis=0)
)
# Out:
# <style type="text/css">
# #T_6ec7b_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6ec7b_row1_col0 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_6ec7b_row2_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_6ec7b_row3_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_6ec7b_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_6ec7b_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >cluster</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >churn</th>
#       <th class="index_name level1" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ec7b_level0_row0" class="row_heading level0 row0" rowspan="5">True</th>
# ...

# %%
# визуализация оттока клиентов
fig = go.Figure(data=[go.Pie(labels=df.query('churn == True')['cluster'].value_counts().index,
                             values=df.query('churn == True')['cluster'].value_counts())])
fig.update_layout(
    width=400,
    height=400,
    title='График доли оттока клиентов'
)
fig.show()
# Out:
# <div>                            <div id="4fc64831-7c5d-4535-b2ec-cc0d87152fcc" class="plotly-graph-div" style="height:400px; width:400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fc64831-7c5d-4535-b2ec-cc0d87152fcc")) {                    Plotly.newPlot(                        "4fc64831-7c5d-4535-b2ec-cc0d87152fcc",                        [{"labels":[0,4,2,1,3],"values":[360,343,220,126,12],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"e
# ...

# %% [markdown]
# больше всего склонность к оттоку у кластера 0 и 4 более 32%, кластер 3 почти не склонен к оттоку всего 1.13%

# %% [markdown]
# ## Формулирование выводов

# %% [markdown]
# После проведенного исследования, подведем основные выводы:
# - Прогнозирование:
# В построении моделей прогнозирования оттока клиентов использованы модели "Логистическая регрессия" и "Случайный лес".
# Модели показали отличные результаты - по параметру Accuracy "Логистическая регрессия" лучше 0.90, чем "Случайный лес" 0.89, по Precision "Логистическая регрессия" и "Случайный лес" получили одинаковые показатели 0.79, по Recall "Логистическая регрессия" лучше 0.81, чем и "Случайный лес" 0.76.
# Почти по всем параметрам "Логистическая регрессия" дает результат немного лучше чем "Случайный лес"
# - Кластеризация:
# В результате анализа было принято решение разбить клиентов на 5 кластеров. Метрика Silhouette_score   показала, что кластеризация прошла некачественно 0.01.
#
# - Кластер 0 - самый плохой кластер, здесь отток 33.93% больше всего: в кластере 0 больше всего, выбирают тариф на 1 месяц, клиенты до 30 лет, меньше всего траты на доп.услуги, больше всего клиентов живущих далеко от клуба, больше всего клиентов пришедших не по акции, клиенты не любят групповые занятия
# - Кластер 1 - хороший кластер, доля оттока около 11.88%:
#     клиентам в основном 30 лет, клиенты ходят более 4 месяцев
# - Кластер 2 - средний кластер, доля оттока 20.74%: клиенты в основном за 30 лет, клиентов больше всего пришедших по акции приведи друга, не любят групповые занятия
# - Кластер 3 - самый хороший кластер, здесь самый маленький ооток 1.13%: чаще выбирают абонемент на 12 месяцев, клиенты в основном за 30 лет, в кластере 3 тратят больше всех на доп.услуги, клиенты ходят более 4 месяцев, клиенты посещают более 2 раз в неделю
# - Кластер 4 - также как и 0 кластер плохой по оттоку 32.33%: в кластере 4 больше всего, выбирают тариф на 1 месяц, клиенты до 30 лет, больше всего клиентов не являются партнерами, больше всего клиентов пришедших не по акции, больше всего тех клиентов, кто не сотавил телефон, не любят групповые занятия
#
#      Рекомендации:
# - предлагать партнерские программы и промо-акции.
# - предлагать новым клиентам более выгодные цены на абонементы за 12 месяцев
# - предложить клиентам заполнить анкету(анонимно) и таким образом выяснить, что не хватает клиентам клуба
# - пересмотреть виды групповых занятий, возможно, какие-то направления не очень популярны
# - ввести занятия для клиентов пенсионного возраста, в дневное время
# - ввести занятия для детей и организовать детский клуб(от 3 до 6 лет), чтобы мамы маленьких детей могли тренироваться, так смогут приходить в клуб семьями
